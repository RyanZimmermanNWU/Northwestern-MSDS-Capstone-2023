# %% [markdown]
# # Overview

# %% [markdown]
# <b> Features: </b>
# 1. Scale: Min-Max/ Standard Scaling
# 2. Log Transform

# %% [markdown]
# # Notebook Set-Up

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)           # prevents scientific notation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Import Data

# %%
github = r'https://raw.githubusercontent.com/mattlibonati/Northwestern-MSDS-Capstone-2023/main/Data/'
github_r = r'https://raw.githubusercontent.com/mattlibonati/Northwestern-MSDS-Capstone-2023/main/Data/raw_data/'

# %%
redfin = pd.read_csv(github+'redfin.csv').drop(columns = ['Unnamed: 0','period_begin','region_type',
                                                          'is_seasonally_adjusted','last_updated','city',
                                                          'period_duration'])

# output data
print('Raw Data:')             
display(redfin)               

# Label Encoding
redfin_strings = redfin.select_dtypes(include=['object'])
redfin_string_encoded = label_encode(redfin_strings)
redfin_encoded = redfin_string_encoded.join(redfin.select_dtypes(exclude=['object']))

print('Standard Scaling:')
display(scale_set(redfin_encoded)[0]) 
print('Min-Max Scaling:')
display(scale_set(redfin_encoded)[1])
print('Log Transformed:')
display(log_transform(redfin_encoded))

# output files to excel
scale_set(redfin_encoded)[0].round(6).to_csv(r'C:\Users\Mattl\Desktop\Data\redfin\redfin_standard_scaled.csv')
scale_set(redfin_encoded)[1].round(6).to_csv(r'C:\Users\Mattl\Desktop\Data\redfin\redfin_minmax_scaled.csv')
log_transform(redfin_encoded).round(6).to_csv(r'C:\Users\Mattl\Desktop\Data\redfin\redfin_log_transformed.csv')
redfin_encoded.round(6).to_csv(r'C:\Users\Mattl\Desktop\Data\redfin\redfin_label_encoded.csv')
# Out:
# Raw Data:
#        period_end  region_type_id  table_id                       region  \
# 0      2017-12-31               5       396           Larimer County, CO
# 1      2016-12-31               5      2932           Orleans County, VT
# 2      2020-12-31               5      1396          Mackinac County, MI
# 3      2019-12-31               5       888            Starke County, IN
# 4      2019-12-31               5      1012            Butler County, KS
# ...           ...             ...       ...                          ...
# 48844  2018-12-31               5       983     Pottawattamie County, IA
# 48845  2016-12-31               5      1124           Bullitt County, KY
# 48846  2016-12-31               5      1246  East Baton Rouge Parish, LA
# 48847  2016-12-31               5      1246  East Baton Rouge Parish, LA
# 48848  2021-12-31               5      2433         Abbeville County, SC
#
#                 state state_code              property_type  property_type_id  \
# 0            Colorado         CO    Multi-Family (2-4 Unit)                 4
# 1             Vermont         VT  Single Family Residential                 6
# 2            Michigan         MI  Single Family Residential                 6
# 3             Indiana         IN  Single Family Residential                 6
# 4              Kansas         KS    Multi-Family (2-4 Unit)                 4
# ...               ...        ...                        ...               ...
# 48844            Iowa         IA            All Residential                -1
# 48845        Kentucky         KY  Single Family Residential                 6
# 48846       Louisiana         LA            All Residential                -1
# 48847       Louisiana         LA                  Townhouse                13
# 48848  South Carolina         SC            All Residential                -1
#
#        median_sale_price  median_sale_price_mom  ...  sold_above_list_mom  \
# 0             465000.000                 -0.016  ...               -0.107
# 1             130100.000                 -0.192  ...               -0.066
# 2             125000.000                    NaN  ...                  NaN
# 3             124900.000                  0.243  ...                0.003
# 4             367000.000                  3.587  ...                1.000
# ...                  ...                    ...  ...                  ...
# 48844         160000.000                  0.231  ...               -0.034
# 48845         166965.500                 -0.017  ...               -0.054
# 48846         167550.000                 -0.043  ...               -0.000
# 48847         105000.000                 -0.160  ...               -0.028
# 48848         205000.000                  0.085  ...                0.221
#
#        sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0                   -0.190          NaN              NaN              NaN
# 1                   -0.041        0.068           -0.037            0.019
# 2                    0.000          NaN              NaN              NaN
# 3                    0.140          NaN              NaN              NaN
# 4                    1.000          NaN              NaN              NaN
# ...                    ...          ...              ...              ...
# 48844                0.099        0.017           -0.035           -0.130
# 48845               -0.051        0.058           -0.075           -0.008
# 48846                0.010        0.118           -0.039            0.004
# 48847               -0.126        0.090            0.022            0.014
# 48848                0.209        0.086           -0.023              NaN
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                        0.000                       -0.333
# 1                        0.000                        0.000
# 2                          NaN                          NaN
# 3                        0.083                        0.083
# 4                        0.000                        0.000
# ...                        ...                          ...
# 48844                    0.025                       -0.175
# 48845                    0.333                       -0.036
# 48846                    0.434                       -0.036
# 48847                    0.364                        0.064
# 48848                    0.000                       -0.067
#
#        off_market_in_two_weeks_yoy                  parent_metro_region  \
# 0                            0.000                     Fort Collins, CO
# 1                           -0.222         Vermont nonmetropolitan area
# 2                              NaN        Michigan nonmetropolitan area
# 3                            0.083         Indiana nonmetropolitan area
# 4                              NaN                          Wichita, KS
# ...                            ...                                  ...
# 48844                       -0.248                            Omaha, NE
# 48845                        0.051                       Louisville, KY
# 48846                        0.126                      Baton Rouge, LA
# 48847                        0.230                      Baton Rouge, LA
# 48848                       -0.200  South Carolina nonmetropolitan area
#
#        parent_metro_region_metro_code
# 0                           22660.000
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                           48620.000
# ...                               ...
# 48844                       36540.000
# 48845                       31140.000
# 48846                       12940.000
# 48847                       12940.000
# 48848                             NaN
#
# [48849 rows x 52 columns]
# Standard Scaling:
#        period_end  region  state  state_code  property_type  \
# 0          -1.119   0.015 -1.464      -1.463          0.176
# 1          -1.626   0.637  1.318       1.426          0.865
# 2           0.401   0.185 -0.252      -0.235          0.865
# 3          -0.105   1.217 -0.822      -0.741          0.865
# 4          -0.105  -1.380 -0.680      -0.669          0.176
# ...           ...     ...    ...         ...            ...
# 48844      -0.612   0.828 -0.751      -0.958         -1.201
# 48845      -1.626  -1.398 -0.608      -0.597          0.865
# 48846      -1.626  -0.812 -0.537      -0.524         -1.201
# 48847      -1.626  -0.812 -0.537      -0.524          1.553
# 48848       0.908  -1.732  0.961       0.992         -1.201
#
#        parent_metro_region  region_type_id  table_id  property_type_id  \
# 0                   -0.762           0.000    -1.368             0.059
# 1                    1.423           0.000     1.387             0.535
# 2                    0.186           0.000    -0.281             0.535
# 3                   -0.381           0.000    -0.833             0.535
# 4                    1.586           0.000    -0.699             0.059
# ...                    ...             ...       ...               ...
# 48844                0.527           0.000    -0.730            -1.133
# 48845               -0.007           0.000    -0.577             0.535
# 48846               -1.562           0.000    -0.444            -1.133
# 48847               -1.562           0.000    -0.444             2.203
# 48848                1.131           0.000     0.845            -1.133
#
#        median_sale_price  ...  sold_above_list  sold_above_list_mom  \
# 0                  0.766  ...           -0.154               -0.490
# 1                 -0.328  ...           -0.586               -0.288
# 2                 -0.345  ...           -0.889                  NaN
# 3                 -0.345  ...            0.064                0.057
# 4                  0.446  ...            4.261                4.989
# ...                  ...  ...              ...                  ...
# 48844             -0.230  ...            0.264               -0.129
# 48845             -0.207  ...           -0.480               -0.226
# 48846             -0.206  ...           -0.306                0.039
# 48847             -0.410  ...           -0.586               -0.099
# 48848             -0.083  ...            0.553                1.135
#
#        sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0                   -0.949          NaN              NaN              NaN
# 1                   -0.247       -0.804            0.128            0.086
# 2                   -0.053          NaN              NaN              NaN
# 3                    0.604          NaN              NaN              NaN
# 4                    4.651          NaN              NaN              NaN
# ...                    ...          ...              ...              ...
# 48844                0.412       -1.247            0.145           -1.505
# 48845               -0.295       -0.891           -0.276           -0.203
# 48846               -0.005       -0.366            0.110           -0.079
# 48847               -0.648       -0.610            0.755            0.028
# 48848                0.928       -0.646            0.275              NaN
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                       -0.868                       -1.443
# 1                       -0.868                        0.058
# 2                          NaN                          NaN
# 3                       -0.514                        0.433
# 4                       -0.868                        0.058
# ...                        ...                          ...
# 48844                   -0.761                       -0.730
# 48845                    0.548                       -0.103
# 48846                    0.975                       -0.104
# 48847                    0.677                        0.345
# 48848                   -0.868                       -0.242
#
#        off_market_in_two_weeks_yoy  parent_metro_region_metro_code
# 0                           -0.080                          -0.644
# 1                           -0.999                             NaN
# 2                              NaN                             NaN
# 3                            0.265                             NaN
# 4                              NaN                           1.620
# ...                            ...                             ...
# 48844                       -1.105                           0.567
# 48845                        0.132                           0.096
# 48846                        0.440                          -1.491
# 48847                        0.873                          -1.491
# 48848                       -0.907                             NaN
#
# [48849 rows x 52 columns]
# Min-Max Scaling:
#        period_end  region  state  state_code  property_type  \
# 0           0.167   0.506  0.104       0.104          0.500
# 1           0.000   0.686  0.917       0.938          0.750
# 2           0.667   0.555  0.458       0.458          0.750
# 3           0.500   0.854  0.292       0.312          0.750
# 4           0.500   0.102  0.333       0.333          0.500
# ...           ...     ...    ...         ...            ...
# 48844       0.333   0.742  0.312       0.250          0.000
# 48845       0.000   0.097  0.354       0.354          0.750
# 48846       0.000   0.267  0.375       0.375          0.000
# 48847       0.000   0.267  0.375       0.375          1.000
# 48848       0.833   0.000  0.812       0.812          0.000
#
#        parent_metro_region  region_type_id  table_id  property_type_id  \
# 0                    0.301           0.000     0.122             0.357
# 1                    0.927           0.000     0.907             0.500
# 2                    0.573           0.000     0.431             0.500
# 3                    0.410           0.000     0.274             0.500
# 4                    0.973           0.000     0.312             0.357
# ...                    ...             ...       ...               ...
# 48844                0.670           0.000     0.304             0.000
# 48845                0.517           0.000     0.347             0.500
# 48846                0.072           0.000     0.385             0.000
# 48847                0.072           0.000     0.385             1.000
# 48848                0.843           0.000     0.752             0.000
#
#        median_sale_price  ...  sold_above_list  sold_above_list_mom  \
# 0                  0.013  ...            0.143                0.446
# 1                  0.004  ...            0.059                0.467
# 2                  0.003  ...            0.000                  NaN
# 3                  0.003  ...            0.185                0.502
# 4                  0.010  ...            1.000                1.000
# ...                  ...  ...              ...                  ...
# 48844              0.004  ...            0.224                0.483
# 48845              0.005  ...            0.080                0.473
# 48846              0.005  ...            0.113                0.500
# 48847              0.003  ...            0.059                0.486
# 48848              0.006  ...            0.280                0.611
#
#        sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0                    0.405          NaN              NaN              NaN
# 1                    0.479        0.068            0.468            0.494
# 2                    0.500          NaN              NaN              NaN
# 3                    0.570          NaN              NaN              NaN
# 4                    1.000          NaN              NaN              NaN
# ...                    ...          ...              ...              ...
# 48844                0.549        0.017            0.469            0.414
# 48845                0.474        0.058            0.446            0.480
# 48846                0.505        0.118            0.467            0.486
# 48847                0.437        0.090            0.501            0.491
# 48848                0.604        0.086            0.476              NaN
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                        0.000                        0.333
# 1                        0.000                        0.500
# 2                          NaN                          NaN
# 3                        0.083                        0.542
# 4                        0.000                        0.500
# ...                        ...                          ...
# 48844                    0.025                        0.412
# 48845                    0.333                        0.482
# 48846                    0.434                        0.482
# 48847                    0.364                        0.532
# 48848                    0.000                        0.467
#
#        off_market_in_two_weeks_yoy  parent_metro_region_metro_code
# 0                            0.500                           0.316
# 1                            0.389                             NaN
# 2                              NaN                             NaN
# 3                            0.542                             NaN
# 4                              NaN                           0.970
# ...                            ...                             ...
# 48844                        0.376                           0.666
# 48845                        0.526                           0.530
# 48846                        0.563                           0.072
# 48847                        0.615                           0.072
# 48848                        0.400                             NaN
#
# [48849 rows x 52 columns]
# Log Transformed:
#        period_end  region  state  state_code  property_type  \
# 0           0.000   7.249  1.609       1.609          0.693
# 1            -inf   7.554  3.784       3.807          1.099
# 2           1.386   7.342  3.091       3.091          1.099
# 3           1.099   7.773  2.639       2.708          1.099
# 4           1.099   5.645  2.773       2.773          0.693
# ...           ...     ...    ...         ...            ...
# 48844       0.693   7.631  2.708       2.485           -inf
# 48845        -inf   5.595  2.833       2.833          1.099
# 48846        -inf   6.608  2.890       2.890           -inf
# 48847        -inf   6.608  2.890       2.890          1.386
# 48848       1.609    -inf  3.664       3.664           -inf
#
#        parent_metro_region  region_type_id  table_id  property_type_id  \
# 0                    5.649           1.609     5.981             1.386
# 1                    6.773           1.609     7.983             1.792
# 2                    6.292           1.609     7.241             1.792
# 3                    5.958           1.609     6.789             1.792
# 4                    6.822           1.609     6.920             1.386
# ...                    ...             ...       ...               ...
# 48844                6.449           1.609     6.891               NaN
# 48845                6.190           1.609     7.025             1.792
# 48846                4.220           1.609     7.128               NaN
# 48847                4.220           1.609     7.128             2.565
# 48848                6.678           1.609     7.797               NaN
#
#        median_sale_price  ...  sold_above_list  sold_above_list_mom  \
# 0                 13.050  ...           -1.946                  NaN
# 1                 11.776  ...           -2.833                  NaN
# 2                 11.736  ...             -inf                  NaN
# 3                 11.735  ...           -1.686               -5.694
# 4                 12.813  ...            0.000                0.000
# ...                  ...  ...              ...                  ...
# 48844             11.983  ...           -1.497                  NaN
# 48845             12.026  ...           -2.531                  NaN
# 48846             12.029  ...           -2.177                  NaN
# 48847             11.562  ...           -2.833                  NaN
# 48848             12.231  ...           -1.273               -1.509
#
#        sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0                      NaN          NaN              NaN              NaN
# 1                      NaN       -2.694              NaN           -3.962
# 2                     -inf          NaN              NaN              NaN
# 3                   -1.968          NaN              NaN              NaN
# 4                    0.000          NaN              NaN              NaN
# ...                    ...          ...              ...              ...
# 48844               -2.314       -4.084              NaN              NaN
# 48845                  NaN       -2.853              NaN              NaN
# 48846               -4.590       -2.139              NaN           -5.630
# 48847                  NaN       -2.409           -3.795           -4.301
# 48848               -1.567       -2.457              NaN              NaN
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                         -inf                          NaN
# 1                         -inf                         -inf
# 2                          NaN                          NaN
# 3                       -2.485                       -2.485
# 4                         -inf                         -inf
# ...                        ...                          ...
# 48844                   -3.689                          NaN
# 48845                   -1.099                          NaN
# 48846                   -0.835                          NaN
# 48847                   -1.012                       -2.755
# 48848                     -inf                          NaN
#
#        off_market_in_two_weeks_yoy  parent_metro_region_metro_code
# 0                             -inf                          10.028
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                           -2.485                             NaN
# 4                              NaN                          10.792
# ...                            ...                             ...
# 48844                          NaN                          10.506
# 48845                       -2.970                          10.346
# 48846                       -2.073                           9.468
# 48847                       -1.468                           9.468
# 48848                          NaN                             NaN
#
# [48849 rows x 52 columns]

# %% [markdown]
# # FHFA

# %%
fhfa = pd.read_csv(github_r+'fhfa_raw.csv')
# limit to 2016--> 2022 year end
fhfa = fhfa[(fhfa['year'].isin([2016,2017,2018,2019,2020,2021,2022])) & (fhfa['qtr'] == 4)]
# pivot on divisons
# fhfa_u = fhfa.pivot(index='year', columns='division', values='index_po_seasonally_adjusted').reset_index()
# fhfa_u.to_csv(r'C:\Users\Mattl\Desktop\Data\fhfa\fhfa.csv')
# display(fhfa_u)
# Out:
# division  year  DV_ENC  DV_ESC   DV_MA   DV_MT   DV_NE  DV_PAC   DV_SA  \
# 0         2016 192.240 211.780 213.610 300.220 218.140 265.280 231.830
# 1         2017 203.110 223.240 223.640 325.960 229.720 287.200 246.110
# 2         2018 214.770 236.590 234.140 352.210 240.650 303.020 260.860
# 3         2019 226.780 250.070 245.440 378.050 252.270 318.660 276.930
# 4         2020 252.040 277.790 273.370 429.860 285.020 357.140 308.010
# 5         2021 288.270 330.800 312.050 530.630 332.390 426.870 371.630
# 6         2022 311.780 365.480 338.330 563.190 358.770 439.430 417.610
#
# division  DV_WNC  DV_WSC     USA
# 0        232.140 247.360 231.200
# 1        244.120 262.230 245.570
# 2        257.810 273.900 259.390
# 3        271.310 286.210 273.680
# 4        298.590 312.500 304.480
# 5        339.990 369.350 358.910
# 6        366.700 403.870 389.080

# %% [markdown]
# # FRED

# %%
fred       = pd.read_csv(github_r+'fred_raw.csv')
fred       = fred[(fred['DATE'] >= '2016-12-31') & (fred['DATE'] < '2023-01-01')]
fred['yr-mo'] = pd.DatetimeIndex(fred['DATE']).year.astype(str) + '-' + pd.DatetimeIndex(fred['DATE']).month.astype(str) 
fred = fred.sort_values('DATE',ascending=False).groupby('yr-mo').head(1)
fred = fred[pd.DatetimeIndex(fred['DATE']).month == 12] 
fred.to_csv(r'C:\Users\Mattl\Desktop\Data\fred.csv')
fred
# Out:
#             DATE  MORTGAGE30US    yr-mo
# 2700  2022-12-29         6.420  2022-12
# 2648  2021-12-30         3.110  2021-12
# 2596  2020-12-31         2.670  2020-12
# 2543  2019-12-26         3.740  2019-12
# 2491  2018-12-27         4.550  2018-12
# 2439  2017-12-28         3.990  2017-12

# %% [markdown]
# # Census Data

# %%
census = pd.read_csv(github+'census.csv').drop(columns = 'NAME')
print('Raw Data:')             
display(census)               

# Label Encoding
census_strings = census.select_dtypes(include=['object'])
census_string_encoded = label_encode(census_strings)
census_encoded = census_string_encoded.join(census.select_dtypes(exclude=['object']))
display(census_encoded)

print('Standard Scaling:')
display(scale_set(census_encoded)[0]) 
print('Min-Max Scaling:')
display(scale_set(census_encoded)[1])
print('Log Transformed:')
display(log_transform(census_encoded))

# output files to excel
# scale_set(census)[0].to_csv(r'C:\Users\Mattl\Desktop\Data\census\census_standard_scaled.csv')
# scale_set(census)[1].to_csv(r'C:\Users\Mattl\Desktop\Data\census\census_minmax_scaled.csv')
# log_transform(census).to_csv(r'C:\Users\Mattl\Desktop\Data\census\census_log_transformed.csv')
# census_encoded.to_csv(r'C:\Users\Mattl\Desktop\Data\census\census_label_encoded.csv')
# Out:
# Raw Data:
#       GEOID  mean_household_size_owner  transportation_drive_alone  \
# 0     20161                      2.480                       28264
# 1     19159                      2.540                        1606
# 2     30009                      2.370                        3575
# 3     16007                      2.960                        1927
# 4     55011                      2.490                        5401
# ...     ...                        ...                         ...
# 3216  53003                      2.330                        7477
# 3217  13043                      2.960                        3650
# 3218  48451                      2.620                       44500
# 3219  39089                      2.700                       67038
# 3220  19193                      2.640                       43104
#
#       transportation_public  one_person_household  more_than_200k      mhhi  \
# 0                        85                  8595            1379 53296.000
# 1                         7                   585              79 57700.000
# 2                        19                  1547             269 63178.000
# 3                        17                   521              81 60337.000
# 4                         7                  1650             136 61167.000
# ...                     ...                   ...             ...       ...
# 3216                     53                  2821             499 57263.000
# 3217                      0                  1288              74 36763.000
# 3218                    132                 13372            1745 62052.000
# 3219                    143                 15584            4999 72771.000
# 3220                    564                 11034            1643 63061.000
#
#       mhhi_family  mhhi_nonfamily  vacant_units  ...  median_number_rooms  \
# 0       76786.000       37950.000          3979  ...                5.300
# 1       76250.000       30345.000           809  ...                6.200
# 2       82083.000       34108.000          1865  ...                5.400
# 3       75882.000       25673.000          1637  ...                6.400
# 4       75954.000       35044.000           992  ...                6.200
# ...           ...             ...           ...  ...                  ...
# 3216    73972.000       37745.000           752  ...                6.000
# 3217    47221.000       18268.000           602  ...                5.300
# 3218    76060.000       35420.000          6226  ...                5.200
# 3219    88792.000       39470.000          6090  ...                6.200
# 3220    76827.000       34683.000          2825  ...                5.900
#
#       median_gross_rent  median_year_built  plumbing_complete  \
# 0               968.000               1984              26554
# 1               639.000               1962               1847
# 2               841.000               1981               4500
# 3               598.000               1971               2223
# 4               730.000               1971               5505
# ...                 ...                ...                ...
# 3216            856.000               1976               9278
# 3217            653.000               1990               4034
# 3218            917.000               1977              44554
# 3219            894.000               1978              66081
# 3220            838.000               1957              39563
#
#       kitchen_complete  median_gross_rent_frac_income  \
# 0                26523                         31.500
# 1                 1840                         29.500
# 2                 4494                         24.400
# 3                 2230                         26.400
# 4                 5505                         25.200
# ...                ...                            ...
# 3216              9255                         28.700
# 3217              4015                         28.000
# 3218             44344                         28.000
# 3219             65809                         26.300
# 3220             39362                         25.900
#
#       lower_quartile_home_value  median_home_value  upper_quartile_home_value  \
# 0                    146900.000         211500.000                 286400.000
# 1                     63800.000         111300.000                 217600.000
# 2                    187800.000         297500.000                 477300.000
# 3                     97200.000         160200.000                 270600.000
# 4                    106800.000         164500.000                 245300.000
# ...                         ...                ...                        ...
# 3216                 155000.000         229300.000                 323700.000
# 3217                  45000.000          94700.000                 203900.000
# 3218                  89800.000         156600.000                 230400.000
# 3219                 129500.000         195100.000                 284300.000
# 3220                  89700.000         139600.000                 206500.000
#
#       electricity_cost
# 0                 2167
# 1                   14
# 2                  367
# 3                  478
# 4                  138
# ...                ...
# 3216               865
# 3217               176
# 3218              2073
# 3219              3439
# 3220              2104
#
# [3221 rows x 24 columns]
#       GEOID  mean_household_size_owner  transportation_drive_alone  \
# 0     20161                      2.480                       28264
# 1     19159                      2.540                        1606
# 2     30009                      2.370                        3575
# 3     16007                      2.960                        1927
# 4     55011                      2.490                        5401
# ...     ...                        ...                         ...
# 3216  53003                      2.330                        7477
# 3217  13043                      2.960                        3650
# 3218  48451                      2.620                       44500
# 3219  39089                      2.700                       67038
# 3220  19193                      2.640                       43104
#
#       transportation_public  one_person_household  more_than_200k      mhhi  \
# 0                        85                  8595            1379 53296.000
# 1                         7                   585              79 57700.000
# 2                        19                  1547             269 63178.000
# 3                        17                   521              81 60337.000
# 4                         7                  1650             136 61167.000
# ...                     ...                   ...             ...       ...
# 3216                     53                  2821             499 57263.000
# 3217                      0                  1288              74 36763.000
# 3218                    132                 13372            1745 62052.000
# 3219                    143                 15584            4999 72771.000
# 3220                    564                 11034            1643 63061.000
#
#       mhhi_family  mhhi_nonfamily  vacant_units  ...  median_number_rooms  \
# 0       76786.000       37950.000          3979  ...                5.300
# 1       76250.000       30345.000           809  ...                6.200
# 2       82083.000       34108.000          1865  ...                5.400
# 3       75882.000       25673.000          1637  ...                6.400
# 4       75954.000       35044.000           992  ...                6.200
# ...           ...             ...           ...  ...                  ...
# 3216    73972.000       37745.000           752  ...                6.000
# 3217    47221.000       18268.000           602  ...                5.300
# 3218    76060.000       35420.000          6226  ...                5.200
# 3219    88792.000       39470.000          6090  ...                6.200
# 3220    76827.000       34683.000          2825  ...                5.900
#
#       median_gross_rent  median_year_built  plumbing_complete  \
# 0               968.000               1984              26554
# 1               639.000               1962               1847
# 2               841.000               1981               4500
# 3               598.000               1971               2223
# 4               730.000               1971               5505
# ...                 ...                ...                ...
# 3216            856.000               1976               9278
# 3217            653.000               1990               4034
# 3218            917.000               1977              44554
# 3219            894.000               1978              66081
# 3220            838.000               1957              39563
#
#       kitchen_complete  median_gross_rent_frac_income  \
# 0                26523                         31.500
# 1                 1840                         29.500
# 2                 4494                         24.400
# 3                 2230                         26.400
# 4                 5505                         25.200
# ...                ...                            ...
# 3216              9255                         28.700
# 3217              4015                         28.000
# 3218             44344                         28.000
# 3219             65809                         26.300
# 3220             39362                         25.900
#
#       lower_quartile_home_value  median_home_value  upper_quartile_home_value  \
# 0                    146900.000         211500.000                 286400.000
# 1                     63800.000         111300.000                 217600.000
# 2                    187800.000         297500.000                 477300.000
# 3                     97200.000         160200.000                 270600.000
# 4                    106800.000         164500.000                 245300.000
# ...                         ...                ...                        ...
# 3216                 155000.000         229300.000                 323700.000
# 3217                  45000.000          94700.000                 203900.000
# 3218                  89800.000         156600.000                 230400.000
# 3219                 129500.000         195100.000                 284300.000
# 3220                  89700.000         139600.000                 206500.000
#
#       electricity_cost
# 0                 2167
# 1                   14
# 2                  367
# 3                  478
# 4                  138
# ...                ...
# 3216               865
# 3217               176
# 3218              2073
# 3219              3439
# 3220              2104
#
# [3221 rows x 24 columns]
# Standard Scaling:
#       GEOID  mean_household_size_owner  transportation_drive_alone  \
# 0    -0.689                     -0.441                      -0.066
# 1    -0.750                     -0.217                      -0.309
# 2    -0.084                     -0.851                      -0.291
# 3    -0.944                      1.349                      -0.306
# 4     1.450                     -0.404                      -0.274
# ...     ...                        ...                         ...
# 3216  1.327                     -1.000                      -0.256
# 3217 -1.126                      1.349                      -0.290
# 3218  1.047                      0.081                       0.081
# 3219  0.473                      0.379                       0.286
# 3220 -0.748                      0.156                       0.069
#
#       transportation_public  one_person_household  more_than_200k   mhhi  \
# 0                    -0.092                -0.069          -0.143 -0.246
# 1                    -0.096                -0.308          -0.225  0.023
# 2                    -0.095                -0.279          -0.213  0.356
# 3                    -0.095                -0.309          -0.224  0.183
# 4                    -0.096                -0.276          -0.221  0.234
# ...                     ...                   ...             ...    ...
# 3216                 -0.093                -0.241          -0.198 -0.004
# 3217                 -0.096                -0.287          -0.225 -1.253
# 3218                 -0.090                 0.073          -0.120  0.288
# 3219                 -0.089                 0.139           0.085  0.941
# 3220                 -0.069                 0.004          -0.126  0.349
#
#       mhhi_family  mhhi_nonfamily  vacant_units  ...  median_number_rooms  \
# 0           0.274           0.496        -0.083  ...               -0.710
# 1           0.246          -0.228        -0.349  ...                0.993
# 2           0.552           0.130        -0.261  ...               -0.521
# 3           0.226          -0.672        -0.280  ...                1.372
# 4           0.230           0.219        -0.334  ...                0.993
# ...           ...             ...           ...  ...                  ...
# 3216        0.126           0.476        -0.354  ...                0.615
# 3217       -1.276          -1.376        -0.367  ...               -0.710
# 3218        0.236           0.255         0.106  ...               -0.900
# 3219        0.903           0.640         0.095  ...                0.993
# 3220        0.276           0.185        -0.180  ...                0.425
#
#       median_gross_rent  median_year_built  plumbing_complete  \
# 0                 0.573              0.157             -0.103
# 1                -0.710             -0.279             -0.312
# 2                 0.077              0.097             -0.289
# 3                -0.870             -0.101             -0.308
# 4                -0.355             -0.101             -0.281
# ...                 ...                ...                ...
# 3216              0.136             -0.002             -0.249
# 3217             -0.656              0.276             -0.293
# 3218              0.374              0.018              0.049
# 3219              0.284              0.038              0.231
# 3220              0.066             -0.378              0.007
#
#       kitchen_complete  median_gross_rent_frac_income  \
# 0               -0.102                          0.949
# 1               -0.312                          0.495
# 2               -0.290                         -0.664
# 3               -0.309                         -0.209
# 4               -0.281                         -0.482
# ...                ...                            ...
# 3216            -0.249                          0.313
# 3217            -0.294                          0.154
# 3218             0.049                          0.154
# 3219             0.232                         -0.232
# 3220             0.007                         -0.323
#
#       lower_quartile_home_value  median_home_value  upper_quartile_home_value  \
# 0                         0.514              0.409                      0.170
# 1                        -0.558             -0.537                     -0.286
# 2                         1.042              1.221                      1.433
# 3                        -0.127             -0.075                      0.065
# 4                        -0.003             -0.034                     -0.103
# ...                         ...                ...                        ...
# 3216                      0.619              0.577                      0.417
# 3217                     -0.801             -0.694                     -0.377
# 3218                     -0.223             -0.109                     -0.201
# 3219                      0.290              0.255                      0.156
# 3220                     -0.224             -0.270                     -0.359
#
#       electricity_cost
# 0               -0.049
# 1               -0.181
# 2               -0.159
# 3               -0.152
# 4               -0.173
# ...                ...
# 3216            -0.129
# 3217            -0.171
# 3218            -0.054
# 3219             0.030
# 3220            -0.052
#
# [3221 rows x 24 columns]
# Min-Max Scaling:
#       GEOID  mean_household_size_owner  transportation_drive_alone  \
# 0     0.269                      0.241                       0.008
# 1     0.255                      0.257                       0.000
# 2     0.408                      0.211                       0.001
# 3     0.211                      0.371                       0.001
# 4     0.759                      0.244                       0.002
# ...     ...                        ...                         ...
# 3216  0.731                      0.201                       0.002
# 3217  0.169                      0.371                       0.001
# 3218  0.667                      0.279                       0.013
# 3219  0.535                      0.301                       0.020
# 3220  0.256                      0.285                       0.013
#
#       transportation_public  one_person_household  more_than_200k  mhhi  \
# 0                     0.000                 0.010           0.003 0.281
# 1                     0.000                 0.001           0.000 0.311
# 2                     0.000                 0.002           0.001 0.350
# 3                     0.000                 0.001           0.000 0.330
# 4                     0.000                 0.002           0.000 0.336
# ...                     ...                   ...             ...   ...
# 3216                  0.000                 0.003           0.001 0.308
# 3217                  0.000                 0.001           0.000 0.166
# 3218                  0.000                 0.016           0.004 0.342
# 3219                  0.000                 0.018           0.012 0.416
# 3220                  0.001                 0.013           0.004 0.349
#
#       mhhi_family  mhhi_nonfamily  vacant_units  ...  median_number_rooms  \
# 0           0.363           0.318         0.017  ...                0.382
# 1           0.360           0.236         0.003  ...                0.500
# 2           0.393           0.276         0.008  ...                0.395
# 3           0.358           0.186         0.007  ...                0.526
# 4           0.358           0.286         0.004  ...                0.500
# ...           ...             ...           ...  ...                  ...
# 3216        0.347           0.315         0.003  ...                0.474
# 3217        0.192           0.107         0.002  ...                0.382
# 3218        0.359           0.290         0.026  ...                0.368
# 3219        0.432           0.334         0.026  ...                0.500
# 3220        0.363           0.283         0.012  ...                0.461
#
#       median_gross_rent  median_year_built  plumbing_complete  \
# 0                 0.308              0.990              0.008
# 1                 0.168              0.979              0.001
# 2                 0.254              0.989              0.001
# 3                 0.151              0.984              0.001
# 4                 0.207              0.984              0.002
# ...                 ...                ...                ...
# 3216              0.260              0.986              0.003
# 3217              0.174              0.993              0.001
# 3218              0.286              0.987              0.013
# 3219              0.276              0.987              0.020
# 3220              0.253              0.977              0.012
#
#       kitchen_complete  median_gross_rent_frac_income  \
# 0                0.008                          0.536
# 1                0.001                          0.488
# 2                0.001                          0.367
# 3                0.001                          0.414
# 4                0.002                          0.386
# ...                ...                            ...
# 3216             0.003                          0.469
# 3217             0.001                          0.452
# 3218             0.013                          0.452
# 3219             0.020                          0.412
# 3220             0.012                          0.402
#
#       lower_quartile_home_value  median_home_value  upper_quartile_home_value  \
# 0                         0.154              0.157                      0.113
# 1                         0.061              0.074                      0.078
# 2                         0.200              0.228                      0.212
# 3                         0.098              0.114                      0.105
# 4                         0.109              0.118                      0.092
# ...                         ...                ...                        ...
# 3216                      0.163              0.172                      0.133
# 3217                      0.039              0.060                      0.071
# 3218                      0.090              0.111                      0.084
# 3219                      0.135              0.143                      0.112
# 3220                      0.090              0.097                      0.072
#
#       electricity_cost
# 0                0.003
# 1                0.000
# 2                0.001
# 3                0.001
# 4                0.000
# ...                ...
# 3216             0.001
# 3217             0.000
# 3218             0.003
# 3219             0.005
# 3220             0.003
#
# [3221 rows x 24 columns]
# Log Transformed:
# C:\Users\Mattl\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#       GEOID  mean_household_size_owner  transportation_drive_alone  \
# 0     9.912                      0.908                      10.249
# 1     9.861                      0.932                       7.382
# 2    10.309                      0.863                       8.182
# 3     9.681                      1.085                       7.564
# 4    10.915                      0.912                       8.594
# ...     ...                        ...                         ...
# 3216 10.878                      0.846                       8.920
# 3217  9.476                      1.085                       8.202
# 3218 10.788                      0.963                      10.703
# 3219 10.574                      0.993                      11.113
# 3220  9.862                      0.971                      10.671
#
#       transportation_public  one_person_household  more_than_200k   mhhi  \
# 0                     4.443                 9.059           7.229 10.884
# 1                     1.946                 6.372           4.369 10.963
# 2                     2.944                 7.344           5.595 11.054
# 3                     2.833                 6.256           4.394 11.008
# 4                     1.946                 7.409           4.913 11.021
# ...                     ...                   ...             ...    ...
# 3216                  3.970                 7.945           6.213 10.955
# 3217                   -inf                 7.161           4.304 10.512
# 3218                  4.883                 9.501           7.465 11.036
# 3219                  4.963                 9.654           8.517 11.195
# 3220                  6.335                 9.309           7.404 11.052
#
#       mhhi_family  mhhi_nonfamily  vacant_units  ...  median_number_rooms  \
# 0          11.249          10.544         8.289  ...                1.668
# 1          11.242          10.320         6.696  ...                1.825
# 2          11.315          10.437         7.531  ...                1.686
# 3          11.237          10.153         7.401  ...                1.856
# 4          11.238          10.464         6.900  ...                1.825
# ...           ...             ...           ...  ...                  ...
# 3216       11.211          10.539         6.623  ...                1.792
# 3217       10.763           9.813         6.400  ...                1.668
# 3218       11.239          10.475         8.736  ...                1.649
# 3219       11.394          10.583         8.714  ...                1.825
# 3220       11.249          10.454         7.946  ...                1.775
#
#       median_gross_rent  median_year_built  plumbing_complete  \
# 0                 6.875              7.593             10.187
# 1                 6.460              7.582              7.521
# 2                 6.735              7.591              8.412
# 3                 6.394              7.586              7.707
# 4                 6.593              7.586              8.613
# ...                 ...                ...                ...
# 3216              6.752              7.589              9.135
# 3217              6.482              7.596              8.303
# 3218              6.821              7.589             10.704
# 3219              6.796              7.590             11.099
# 3220              6.731              7.579             10.586
#
#       kitchen_complete  median_gross_rent_frac_income  \
# 0               10.186                          3.450
# 1                7.518                          3.384
# 2                8.410                          3.195
# 3                7.710                          3.273
# 4                8.613                          3.227
# ...                ...                            ...
# 3216             9.133                          3.357
# 3217             8.298                          3.332
# 3218            10.700                          3.332
# 3219            11.095                          3.270
# 3220            10.581                          3.254
#
#       lower_quartile_home_value  median_home_value  upper_quartile_home_value  \
# 0                        11.898             12.262                     12.565
# 1                        11.064             11.620                     12.290
# 2                        12.143             12.603                     13.076
# 3                        11.485             11.984                     12.508
# 4                        11.579             12.011                     12.410
# ...                         ...                ...                        ...
# 3216                     11.951             12.343                     12.688
# 3217                     10.714             11.458                     12.225
# 3218                     11.405             11.961                     12.348
# 3219                     11.771             12.181                     12.558
# 3220                     11.404             11.847                     12.238
#
#       electricity_cost
# 0                7.681
# 1                2.639
# 2                5.905
# 3                6.170
# 4                4.927
# ...                ...
# 3216             6.763
# 3217             5.170
# 3218             7.637
# 3219             8.143
# 3220             7.652
#
# [3221 rows x 24 columns]
# C:\Users\Mattl\anaconda3\lib\site-packages\pandas\core\arraylike.py:402: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# # Merge Data

# %%
github = r'https://raw.githubusercontent.com/mattlibonati/Northwestern-MSDS-Capstone-2023/main/Data/'

fhfa   = pd.read_csv(github+'fhfa.csv').drop(columns = ['Unnamed: 0'])
fred   = pd.read_csv(github+'fred.csv').drop(columns = ['Unnamed: 0'])
census = pd.read_csv(github+'census.csv')
redfin = pd.read_csv(github+'redfin.csv').drop(columns = ['Unnamed: 0','period_begin'])

display(fhfa.head())
display(fred.head())
display(census.head())
display(redfin.head())
# Out:
#    year  DV_ENC  DV_ESC   DV_MA   DV_MT   DV_NE  DV_PAC   DV_SA  DV_WNC  \
# 0  2016 192.240 211.780 213.610 300.220 218.140 265.280 231.830 232.140
# 1  2017 203.110 223.240 223.640 325.960 229.720 287.200 246.110 244.120
# 2  2018 214.770 236.590 234.140 352.210 240.650 303.020 260.860 257.810
# 3  2019 226.780 250.070 245.440 378.050 252.270 318.660 276.930 271.310
# 4  2020 252.040 277.790 273.370 429.860 285.020 357.140 308.010 298.590
#
#    DV_WSC     USA
# 0 247.360 231.200
# 1 262.230 245.570
# 2 273.900 259.390
# 3 286.210 273.680
# 4 312.500 304.480
#          DATE  MORTGAGE30US    yr-mo
# 0  2022-12-29         6.420  2022-12
# 1  2021-12-30         3.110  2021-12
# 2  2020-12-31         2.670  2020-12
# 3  2019-12-26         3.740  2019-12
# 4  2018-12-27         4.550  2018-12
#    GEOID                       NAME  mean_household_size_owner  \
# 0  20161       Riley County, Kansas                      2.480
# 1  19159      Ringgold County, Iowa                      2.540
# 2  30009     Carbon County, Montana                      2.370
# 3  16007    Bear Lake County, Idaho                      2.960
# 4  55011  Buffalo County, Wisconsin                      2.490
#
#    transportation_drive_alone  transportation_public  one_person_household  \
# 0                       28264                     85                  8595
# 1                        1606                      7                   585
# 2                        3575                     19                  1547
# 3                        1927                     17                   521
# 4                        5401                      7                  1650
#
#    more_than_200k      mhhi  mhhi_family  mhhi_nonfamily  ...  \
# 0            1379 53296.000    76786.000       37950.000  ...
# 1              79 57700.000    76250.000       30345.000  ...
# 2             269 63178.000    82083.000       34108.000  ...
# 3              81 60337.000    75882.000       25673.000  ...
# 4             136 61167.000    75954.000       35044.000  ...
#
#    median_number_rooms  median_gross_rent  median_year_built  \
# 0                5.300            968.000               1984
# 1                6.200            639.000               1962
# 2                5.400            841.000               1981
# 3                6.400            598.000               1971
# 4                6.200            730.000               1971
#
#    plumbing_complete  kitchen_complete  median_gross_rent_frac_income  \
# 0              26554             26523                         31.500
# 1               1847              1840                         29.500
# 2               4500              4494                         24.400
# 3               2223              2230                         26.400
# 4               5505              5505                         25.200
#
#    lower_quartile_home_value  median_home_value  upper_quartile_home_value  \
# 0                 146900.000         211500.000                 286400.000
# 1                  63800.000         111300.000                 217600.000
# 2                 187800.000         297500.000                 477300.000
# 3                  97200.000         160200.000                 270600.000
# 4                 106800.000         164500.000                 245300.000
#
#    electricity_cost
# 0              2167
# 1                14
# 2               367
# 3               478
# 4               138
#
# [5 rows x 25 columns]
#    period_end  period_duration region_type  region_type_id  table_id  \
# 0  2017-12-31               30      county               5       396
# 1  2016-12-31               30      county               5      2932
# 2  2020-12-31               30      county               5      1396
# 3  2019-12-31               30      county               5       888
# 4  2019-12-31               30      county               5      1012
#
#   is_seasonally_adjusted               region  city     state state_code  ...  \
# 0                      f   Larimer County, CO   NaN  Colorado         CO  ...
# 1                      f   Orleans County, VT   NaN   Vermont         VT  ...
# 2                      f  Mackinac County, MI   NaN  Michigan         MI  ...
# 3                      f    Starke County, IN   NaN   Indiana         IN  ...
# 4                      f    Butler County, KS   NaN    Kansas         KS  ...
#
#   sold_above_list_yoy  price_drops  price_drops_mom  price_drops_yoy  \
# 0              -0.190          NaN              NaN              NaN
# 1              -0.041        0.068           -0.037            0.019
# 2               0.000          NaN              NaN              NaN
# 3               0.140          NaN              NaN              NaN
# 4               1.000          NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                    0.000                       -0.333
# 1                    0.000                        0.000
# 2                      NaN                          NaN
# 3                    0.083                        0.083
# 4                    0.000                        0.000
#
#    off_market_in_two_weeks_yoy            parent_metro_region  \
# 0                        0.000               Fort Collins, CO
# 1                       -0.222   Vermont nonmetropolitan area
# 2                          NaN  Michigan nonmetropolitan area
# 3                        0.083   Indiana nonmetropolitan area
# 4                          NaN                    Wichita, KS
#
#    parent_metro_region_metro_code  last_updated
# 0                       22660.000     3/19/2023
# 1                             NaN     3/19/2023
# 2                             NaN     3/19/2023
# 3                             NaN     3/19/2023
# 4                       48620.000     3/19/2023
#
# [5 rows x 57 columns]

# %% [markdown]
# # Functions

# %% [markdown]
# Scaling Functions

# %%
# Sklearn standardscaler library
# also look at min-max scaling
from sklearn.preprocessing import StandardScaler, MinMaxScaler

def scale_set(df):
    x = df.loc[:, :].values
    x_ss = pd.DataFrame(StandardScaler().fit_transform(x), columns = df.columns)
    x_mm = pd.DataFrame(MinMaxScaler().fit_transform(x), columns = df.columns)
    return x_ss, x_mm

# %% [markdown]
# Log Transformations

# %%
import numpy as np

def log_transform(df):
    df_log = df.copy()
    for col in df_log.columns:
        df_log[col] = round(np.log(df_log[col]),3)
    return df_log

# %% [markdown]
# Label Encoding

# %%
###################################
# label encoded dataset 
from sklearn import preprocessing

def label_encode(data):
    label_encoder = preprocessing.LabelEncoder()

    label_encoded_df = data.copy()

    for col in label_encoded_df.columns:
        label_encoded_df[col]= label_encoder.fit_transform(label_encoded_df[col])

    label_encoded_df = label_encoded_df.fillna(0)

    return label_encoded_df
