# %% [markdown]
# # Import Dataset

# %%
pd.set_option('display.max_columns', None)

import pandas as pd

directory = r'https://raw.githubusercontent.com/mattlibonati/Northwestern-MSDS-Capstone-2023/main/Data/'

data = pd.read_csv(directory + 'final_data_segmented.csv')

print(data.shape)
data.head()
# Out:
# (3143, 94)
#    fips     county_name    state  attained_bachelors  attained_doctorate  \
# 0  1001  Autauga County  Alabama            0.164260            0.011713
# 1  1003  Baldwin County  Alabama            0.206072            0.013829
# 2  1005  Barbour County  Alabama            0.067352            0.006168
# 3  1007     Bibb County  Alabama            0.079467            0.004235
# 4  1009   Blount County  Alabama            0.093022            0.004426
#
#    attained_masters  attained_professional     black  black_homeowners  \
# 0          0.092114               0.013228  0.196844          0.560549
# 1          0.085716               0.018885  0.086950          0.628894
# 2          0.028897               0.009114  0.472465          0.540083
# 3          0.029644               0.005792  0.218856          0.597826
# 4          0.044556               0.007033  0.012669          0.890756
#
#    eight_rooms  electricity_cost  five_rooms  four_rooms  kitchen_complete  \
# 0     0.104427          0.008419    0.192098    0.115184          0.993228
# 1     0.097632          0.008269    0.215517    0.150744          0.993268
# 2     0.059827          0.014195    0.234165    0.166795          0.994278
# 3     0.070010          0.002118    0.247864    0.146788          0.984470
# 4     0.097077          0.006526    0.245852    0.129001          0.991502
#
#    lower_quartile_home_value  mean_household_size_owner  \
# 0                    91400.0                       2.72
# 1                   151300.0                       2.64
# 2                    44000.0                       2.48
# 3                    60200.0                       3.03
# 4                    79200.0                       2.86
#
#    mean_household_size_renter  median_age  median_gross_rent  \
# 0                        2.40        38.5             1085.0
# 1                        2.35        43.4             1093.0
# 2                        2.41        40.2              605.0
# 3                        2.70        39.7              744.0
# 4                        2.28        41.1              691.0
#
#    median_gross_rent_frac_income  median_home_value  median_number_rooms  \
# 0                           25.4           164900.0                  6.0
# 1                           28.9           226600.0                  5.8
# 2                           25.9            89500.0                  5.3
# 3                           29.1           102900.0                  5.7
# 4                           27.4           138100.0                  5.8
#
#    median_year_built     mhhi  mhhi_family  mhhi_nonfamily  more_than_200k  \
# 0               1992  62660.0      72441.0         31338.0        0.046761
# 1               1996  64346.0      82801.0         35140.0        0.070914
# 2               1980  36422.0      48768.0         20704.0        0.032901
# 3               1985  54277.0      67979.0         22535.0        0.033037
# 4               1989  52830.0      68945.0         23818.0        0.037136
#
#    one_person_household  one_room  owners_25_34  plumbing_complete  \
# 0              0.260752  0.006992      0.136378           0.994967
# 1              0.291433  0.012697      0.090316           0.997270
# 2              0.329776  0.003514      0.100637           0.997909
# 3              0.271072  0.008765      0.046953           0.993082
# 4              0.255493  0.007257      0.109339           0.994413
#
#    renter_occupied  seven_rooms  six_rooms  three_rooms  total_pop  \
# 0         0.257549     0.159578   0.235499     0.048283      58239
# 1         0.228788     0.133793   0.217077     0.049810     227131
# 2         0.377861     0.121797   0.192937     0.117511      25259
# 3         0.212198     0.142905   0.241540     0.032176      22412
# 4         0.208216     0.133730   0.217189     0.034166      58884
#
#    transportation_drive_alone  transportation_public  two_rooms  \
# 0                    0.864011               0.005443   0.009764
# 1                    0.814019               0.001296   0.011966
# 2                    0.831226               0.000827   0.020828
# 3                    0.869652               0.000000   0.014646
# 4                    0.864203               0.001254   0.009459
#
#    upper_quartile_home_value  vacant_units     white  unemployed_rate_q1_22  \
# 0                   243000.0      0.095739  0.730971               2.466667
# 1                   354100.0      0.283937  0.825726               2.600000
# 2                   166600.0      0.221051  0.446098               4.333333
# 3                   174000.0      0.214135  0.740496               2.666667
# 4                   222900.0      0.131569  0.859232               2.400000
#
#    unemployed_rate_q2_22  unemployed_rate_q3_22  unemployed_rate_q4_22  \
# 0               2.200000               2.466667               2.033333
# 1               2.233333               2.500000               2.100000
# 2               3.533333               4.166667               4.200000
# 3               2.300000               2.800000               2.266667
# 4               2.166667               2.366667               2.000000
#
#    unemployed_rate_year_22  \
# 0                 2.291667
# 1                 2.358333
# 2                 4.058333
# 3                 2.508333
# 4                 2.233333
#
#    emp_location_quotient_natural_resources_and_mining  \
# 0                                               1.29
# 1                                               0.80
# 2                                               2.88
# 3                                               1.08
# 4                                               0.62
#
#    emp_location_quotient_construction  emp_location_quotient_manufacturing  \
# 0                                0.82                                 1.56
# 1                                1.23                                 0.56
# 2                                0.39                                 3.24
# 3                                2.62                                 1.57
# 4                                1.30                                 1.75
#
#    emp_location_quotient_trade_transportation_and_utilities  \
# 0                                               1.08
# 1                                               1.25
# 2                                               0.89
# 3                                               1.21
# 4                                               1.03
#
#    emp_location_quotient_information  \
# 0                               0.10
# 1                               0.27
# 2                               0.09
# 3                               0.00
# 4                               0.32
#
#    emp_location_quotient_financial_activities  \
# 0                                        0.62
# 1                                        0.97
# 2                                        0.47
# 3                                        0.34
# 4                                        0.50
#
#    emp_location_quotient_professional_and_business_services  \
# 0                                               0.44
# 1                                               0.58
# 2                                               0.41
# 3                                               0.18
# 4                                               0.36
#
#    emp_location_quotient_education_and_health_services  \
# 0                                               0.70
# 1                                               0.86
# 2                                               0.64
# 3                                               0.73
# 4                                               0.74
#
#    emp_location_quotient_leisure_and_hospitality  \
# 0                                           1.40
# 1                                           2.00
# 2                                           0.89
# 3                                           0.38
# 4                                           1.01
#
#    emp_location_quotient_other_services  emp_location_quotient_unclassified  \
# 0                                  0.86                                 NaN
# 1                                  0.90                                 NaN
# 2                                  0.54                                 NaN
# 3                                  0.00                                 NaN
# 4                                  1.24                                 NaN
#
#    wage_location_quotient_natural_resources_and_mining  \
# 0                                               2.34
# 1                                               0.93
# 2                                               4.20
# 3                                               1.10
# 4                                               0.59
#
#    wage_location_quotient_construction  wage_location_quotient_manufacturing  \
# 0                                 0.91                                  2.00
# 1                                 1.53                                  0.62
# 2                                 0.54                                  3.12
# 3                                 3.88                                  1.53
# 4                                 1.50                                  1.78
#
#    wage_location_quotient_trade_transportation_and_utilities  \
# 0                                               1.22
# 1                                               1.44
# 2                                               1.08
# 3                                               1.24
# 4                                               1.24
#
#    wage_location_quotient_information  \
# 0                                0.07
# 1                                0.17
# 2                                0.05
# 3                                0.00
# 4                                0.23
#
#    wage_location_quotient_financial_activities  \
# 0                                         0.44
# 1                                         0.78
# 2                                         0.32
# 3                                         0.17
# 4                                         0.41
#
#    wage_location_quotient_professional_and_business_services  \
# 0                                               0.40
# 1                                               0.48
# 2                                               0.24
# 3                                               0.17
# 4                                               0.34
#
#    wage_location_quotient_education_and_health_services  \
# 0                                               0.75
# 1                                               1.17
# 2                                               0.74
# 3                                               0.84
# 4                                               0.86
#
#    wage_location_quotient_leisure_and_hospitality  \
# 0                                            1.30
# 1                                            2.78
# 2                                            0.85
# 3                                            0.31
# 4                                            0.94
#
#    wage_location_quotient_other_services  wage_location_quotient_unclassified  \
# 0                                   0.89                                  NaN
# 1                                   1.26                                  NaN
# 2                                   0.68                                  NaN
# 3                                   0.00                                  NaN
# 4                                   1.56                                  NaN
#
#    house_price_jan_2022  house_price_feb_2022  house_price_mar_2022  \
# 0           203508.2843           205676.8716           207975.2387
# 1           322932.6520           327953.6689           333263.6255
# 2           120942.4073           120917.8835           120486.8660
# 3           155812.9473           157805.4675           159430.6529
# 4           184019.3816           186828.1001           190183.0619
#
#    house_price_apr_2022  house_price_may_2022  house_price_jun_2022  \
# 0           210756.1019           213627.9869           216100.3557
# 1           338911.1683           343878.5417           348584.2422
# 2           120376.2874           120717.4623           121898.6474
# 3           160280.3090           161216.5497           163468.3033
# 4           193478.4293           196269.7197           198280.4859
#
#    house_price_july_2022  house_price_aug_2022  house_price_sep_2022  \
# 0            217490.3202           218100.7637           218175.2535
# 1            351403.9297           353147.1005           353390.2407
# 2            123191.0491           124317.9026           124396.3369
# 3            165450.8886           166732.5709           166448.7974
# 4            199263.5361           199622.8086           199468.6190
#
#    house_price_oct_2022  house_price_nov_2022  house_price_dec_2022  \
# 0           218405.2116           218632.3512           218954.0108
# 1           353547.4029           353692.8710           353344.0353
# 2           123950.6964           123286.9935           123113.4927
# 3           165881.5166           165189.7968           164670.1321
# 4           199202.9113           198561.5412           197974.3484
#
#    house_price_jan_2023  house_price_feb_2023  house_price_mar_2023  \
# 0           220077.1351           221399.3258           223375.8158
# 1           353140.6344           353350.2733           354946.1571
# 2           125473.3264           128429.2543           131700.0869
# 3           167023.1576           169847.9001           173319.0282
# 4           200420.5188           203781.9681           207995.4975
#
#    house_price_avg_q1_2022  house_price_avg_q2_2022  house_price_avg_q3_2022  \
# 0              205720.1315              213494.8148              217922.1125
# 1              328049.9821              343791.3174              352647.0903
# 2              120782.3856              120997.4657              123968.4295
# 3              157683.0226              161655.0540              166210.7523
# 4              187010.1812              196009.5450              199451.6546
#
#    house_price_avg_q4_2022  house_price_avg_q1_2023  house_price_avg_2022  \
# 0              218663.8579              221617.4256           213950.2292
# 1              353528.1031              353812.3549           344504.1232
# 2              123450.3942              128534.2225           122299.6688
# 3              165247.1485              170063.3620           162698.9943
# 4              198579.6003              204065.9948           195262.7453
#
#    final_log_mm_k  final_log_ss_k  final_mm_k  final_ss_k
# 0               0               4           2           0
# 1               0               4           2           2
# 2               3               0           2           3
# 3               1               3           2           0
# 4               1               3           2           0

# %% [markdown]
# # Plot Data

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 3,figsize=(10,4))

axs[0].hist(data.median_age)
axs[0].set_title('median_age')
axs[1].hist(data.median_home_value)
axs[1].set_title('median_home_value')
axs[2].hist(data.emp_location_quotient_financial_activities)
axs[2].set_title('emp_location_quotient_financial_activities')

fig.tight_layout()

# Values by Cluster
pd.set_option('display.max_columns', None)
data.groupby('final_log_mm_k')[['median_age','median_home_value','emp_location_quotient_financial_activities']].describe()
# Out:
#                median_age                                                 \
#                     count       mean       std   min   25%   50%     75%
# final_log_mm_k
# 0                   784.0  40.661607  5.791999  22.4  37.1  40.1  43.600
# 1                   595.0  42.556639  4.263936  29.9  40.2  42.4  45.000
# 2                   306.0  41.104902  6.267429  23.3  37.0  39.7  44.475
# 3                   617.0  41.830308  4.605633  24.1  39.3  41.6  44.300
# 4                   841.0  41.386920  5.698163  23.6  38.2  41.3  44.600
#
#                      median_home_value                                \
#                  max             count           mean            std
# final_log_mm_k
# 0               59.8             783.0  209533.588761   38269.531172
# 1               57.8             594.0  123798.316498   29329.829831
# 2               68.1             306.0  409624.183007  163496.025730
# 3               59.8             617.0   90231.928687   17504.087695
# 4               60.5             840.0  136076.190476   30613.144711
#
#                                                                    \
#                      min       25%       50%       75%        max
# final_log_mm_k
# 0               109400.0  177200.0  205500.0  235750.0   328200.0
# 1                22600.0  102950.0  120150.0  144900.0   228300.0
# 2               227300.0  308825.0  354850.0  445300.0  1225900.0
# 3                28700.0   79000.0   89100.0  102200.0   175200.0
# 4                51700.0  117100.0  132950.0  151750.0   406500.0
#
#                emp_location_quotient_financial_activities                      \
#                                                     count      mean       std
# final_log_mm_k
# 0                                                   783.0  0.643959  0.394554
# 1                                                   587.0  0.614344  0.332048
# 2                                                   306.0  0.820425  0.443813
# 3                                                   617.0  0.514019  0.297500
# 4                                                   838.0  0.528616  0.250731
#
#
#                 min    25%    50%    75%   max
# final_log_mm_k
# 0               0.0  0.435  0.560  0.770  5.31
# 1               0.0  0.445  0.590  0.780  2.57
# 2               0.0  0.550  0.715  0.975  2.95
# 3               0.0  0.360  0.490  0.650  3.65
# 4               0.0  0.380  0.510  0.650  1.88

# %% [markdown]
# # "Custom Search"

# %%
min_median_age, max_median_age = input('Min Median Age: '), input('Max Median Age: ') 
min_median_home_value, max_median_home_value = input('Min Median Home Value: '), input('Max Median Home Value: ')
min_emp_quotient_fin = input('Min Finance Employment Quotient: ')

recommendation = data[(data['median_age'] >= float(min_median_age)) & (data['median_age'] <= float(max_median_age)) \
                     & (data['median_home_value'] >= float(min_median_home_value)) & (data['median_home_value'] <= float(max_median_home_value)) \
                     & (data['emp_location_quotient_financial_activities'] >= float(min_emp_quotient_fin))]
recommendation
# Out:
# Min Median Age: 20
# Max Median Age: 30
# Min Median Home Value: 300000
# Max Median Home Value: 400000
# Min Finance Employment Quotient: .5
#        fips        county_name     state  attained_bachelors  \
# 2802  49049        Utah County      Utah            0.293594
# 2952  51830  Williamsburg city  Virginia            0.269279
#
#       attained_doctorate  attained_masters  attained_professional     black  \
# 2802            0.017206          0.094887               0.017197  0.005888
# 2952            0.055137          0.135268               0.044712  0.156154
#
#       black_homeowners  eight_rooms  ...  house_price_avg_q1_2022  \
# 2802          0.394619     0.109440  ...              525998.2968
# 2952          0.283333     0.062082  ...              347301.3890
#
#       house_price_avg_q2_2022  house_price_avg_q3_2022  \
# 2802              552830.4994              552512.5119
# 2952              357543.6999              363091.3660
#
#       house_price_avg_q4_2022  house_price_avg_q1_2023  house_price_avg_2022  \
# 2802              535650.7991              525820.8632           541748.0268
# 2952              363990.4891              366297.2282           357981.7360
#
#       final_log_mm_k  final_log_ss_k  final_mm_k  final_ss_k
# 2802               2               2           0           1
# 2952               2               2           0           2
#
# [2 rows x 94 columns]

# %%
# Out:
#                median_age                                                 \
#                     count       mean       std   min   25%   50%     75%
# final_log_mm_k
# 0                   784.0  40.661607  5.791999  22.4  37.1  40.1  43.600
# 1                   595.0  42.556639  4.263936  29.9  40.2  42.4  45.000
# 2                   306.0  41.104902  6.267429  23.3  37.0  39.7  44.475
# 3                   617.0  41.830308  4.605633  24.1  39.3  41.6  44.300
# 4                   841.0  41.386920  5.698163  23.6  38.2  41.3  44.600
#
#                      median_home_value                                \
#                  max             count           mean            std
# final_log_mm_k
# 0               59.8             783.0  209533.588761   38269.531172
# 1               57.8             594.0  123798.316498   29329.829831
# 2               68.1             306.0  409624.183007  163496.025730
# 3               59.8             617.0   90231.928687   17504.087695
# 4               60.5             840.0  136076.190476   30613.144711
#
#                                                                    \
#                      min       25%       50%       75%        max
# final_log_mm_k
# 0               109400.0  177200.0  205500.0  235750.0   328200.0
# 1                22600.0  102950.0  120150.0  144900.0   228300.0
# 2               227300.0  308825.0  354850.0  445300.0  1225900.0
# 3                28700.0   79000.0   89100.0  102200.0   175200.0
# 4                51700.0  117100.0  132950.0  151750.0   406500.0
#
#                emp_location_quotient_financial_activities                      \
#                                                     count      mean       std
# final_log_mm_k
# 0                                                   783.0  0.643959  0.394554
# 1                                                   587.0  0.614344  0.332048
# 2                                                   306.0  0.820425  0.443813
# 3                                                   617.0  0.514019  0.297500
# 4                                                   838.0  0.528616  0.250731
#
#
#                 min    25%    50%    75%   max
# final_log_mm_k
# 0               0.0  0.435  0.560  0.770  5.31
# 1               0.0  0.445  0.590  0.780  2.57
# 2               0.0  0.550  0.715  0.975  2.95
# 3               0.0  0.360  0.490  0.650  3.65
# 4               0.0  0.380  0.510  0.650  1.88

# %%
# add some sort of rank ordering which considerds local distance to target cluster

fips = input('Fips of Like City: ')

target_cluster = data.query(f"fips == {fips}")[['final_log_mm_k']].values[0][0]

data.query(f'final_log_mm_k == {target_cluster}')
# Out:
# Fips of Like City: 49049
#        fips                county_name       state  attained_bachelors  \
# 69     2020     Anchorage Municipality      Alaska            0.228180
# 79     2110    Juneau City and Borough      Alaska            0.259517
# 81     2130  Ketchikan Gateway Borough      Alaska            0.178655
# 82     2150      Kodiak Island Borough      Alaska            0.187830
# 85     2170  Matanuska-Susitna Borough      Alaska            0.156012
# ...     ...                        ...         ...                 ...
# 2990  53073             Whatcom County  Washington            0.224025
# 3060  55025                Dane County   Wisconsin            0.316143
# 3115  55133            Waukesha County   Wisconsin            0.312519
# 3131  56023             Lincoln County     Wyoming            0.157055
# 3139  56039               Teton County     Wyoming            0.382694
#
#       attained_doctorate  attained_masters  attained_professional     black  \
# 69              0.013455          0.098075               0.028012  0.051602
# 79              0.019713          0.088185               0.033206  0.009646
# 81              0.009081          0.064075               0.012040  0.007748
# 82              0.011115          0.077692               0.015157  0.008927
# 85              0.007794          0.060190               0.013153  0.013098
# ...                  ...               ...                    ...       ...
# 2990            0.021893          0.095819               0.022093  0.009010
# 3060            0.041490          0.138254               0.034421  0.049558
# 3115            0.015084          0.112393               0.028598  0.015427
# 3131            0.008205          0.052016               0.012230  0.000720
# 3139            0.020896          0.147007               0.028088  0.007119
#
#       black_homeowners  eight_rooms  ...  house_price_avg_q1_2022  \
# 69            0.404384     0.082894  ...             3.604911e+05
# 79            0.045977     0.064703  ...             4.565148e+05
# 81            0.161290     0.059567  ...             3.742617e+05
# 82            0.000000     0.080348  ...             3.712010e+05
# 85            0.848485     0.062819  ...             3.231423e+05
# ...                ...          ...  ...                      ...
# 2990          0.368249     0.077956  ...             5.726607e+05
# 3060          0.174394     0.091151  ...             3.715290e+05
# 3115          0.302730     0.124051  ...             3.816063e+05
# 3131               NaN     0.102523  ...             4.004580e+05
# 3139          0.000000     0.064127  ...             1.450559e+06
#
#       house_price_avg_q2_2022  house_price_avg_q3_2022  \
# 69               3.703467e+05             3.744282e+05
# 79               4.649741e+05             4.692767e+05
# 81               3.839985e+05             3.938941e+05
# 82               3.798616e+05             3.927909e+05
# 85               3.262003e+05             3.300663e+05
# ...                       ...                      ...
# 2990             6.077427e+05             6.089991e+05
# 3060             3.861820e+05             3.904562e+05
# 3115             3.942845e+05             3.972215e+05
# 3131             4.314013e+05             4.441682e+05
# 3139             1.558608e+06             1.554250e+06
#
#       house_price_avg_q4_2022  house_price_avg_q1_2023  house_price_avg_2022  \
# 69               3.729142e+05             3.728452e+05          3.695451e+05
# 79               4.661818e+05             4.618228e+05          4.642369e+05
# 81               3.942333e+05             3.912360e+05          3.865969e+05
# 82               3.914753e+05             3.835513e+05          3.838322e+05
# 85               3.283489e+05             3.268010e+05          3.269394e+05
# ...                       ...                      ...                   ...
# 2990             5.896259e+05             5.741234e+05          5.947571e+05
# 3060             3.878179e+05             3.902393e+05          3.839963e+05
# 3115             3.947448e+05             3.979467e+05          3.919643e+05
# 3131             4.588613e+05             4.653133e+05          4.337222e+05
# 3139             1.562388e+06             1.638108e+06          1.531451e+06
#
#       final_log_mm_k  final_log_ss_k  final_mm_k  final_ss_k
# 69                 2               2           0           2
# 79                 2               2           0           1
# 81                 2               2           3           2
# 82                 2               2           3           2
# 85                 2               2           2           2
# ...              ...             ...         ...         ...
# 2990               2               2           0           1
# 3060               2               2           0           1
# 3115               2               2           0           2
# 3131               2               2           1           2
# 3139               2               2           0           4
#
# [306 rows x 94 columns]
